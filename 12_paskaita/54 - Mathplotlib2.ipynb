# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Realaus pasaulio pavyzdžiai

# %% [markdown]
# ## Linijinė diagrama

# %%
plt.title('Kuro kainų pokytis 1990-2008')

plt.plot(gas['Year'], gas['USA'], label='USA')
plt.plot(gas['Year'], gas['Japan'], label='Japan')
plt.plot(gas['Year'], gas['Mexico'], label='Mexico')

years = gas['Year'][::3]
plt.xticks(years)
plt.xlabel('Metai')
plt.ylabel('Kaina')
plt.legend()

plt.show()

# %% [markdown]
# ## Fifa duomenų užkrovimas

# %%
fifa = pd.read_csv("fifa_data.csv")
fifa.shape
# Out:
# (18207, 89)

# %% [markdown]
# ## Histograma

# %%
bins = [40,50,60,70,80,90,100]

plt.hist(fifa['Overall'], bins=bins)
plt.ylabel('zaideju skaicius')
plt.xlabel('Igudziu taskai')
plt.title('Pasiskirtsymas pagal Overral stats')

plt.show()

# %% [markdown]
# ## Skritulinė diagrama

# %%
left = fifa[fifa['Preferred Foot'] == 'Left'].shape[0]
right = fifa[fifa['Preferred Foot'] == 'Right'].shape[0]
right

plt.pie([left, right], labels=['kaire', 'desine'], colors=['red', 'blue'], autopct='%.2f %%')
plt.title('zaideju pagrindine koja')
plt.show()

# %% [markdown]
# ## Uždaviniai

# %% [markdown]
# ### Užduotis 1
# - nusiskaitykite failo employees.csv duomenis
# - Skritulinėje diagramoje atvaizduokite 10 pareigų, kurias turintys darbuotojai uždirba daugiausiai. Atvaizduokite algas procentais, su dviem  simboliais po kablelio.
# - bar diagramoje atvaizduokite 'gender' reišmes ir kiekius. Jei reikia, pasukite x ašyje esančius "labels" 90 kampu.

# %% [markdown]
# ### Užduotis 2
# - nuskaitykite duomenis iš sales_data.csv failo
# - grafike parodykite TV išlaidų pasiskirstymą
# - Pie diagramoje parodykite kiekius pagal "Influencer" reikšmes. Atvaizduokite reikšmes procentais, su trim simboliais po kablelio.
